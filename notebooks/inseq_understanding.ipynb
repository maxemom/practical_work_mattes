# %%
import inseq

model = inseq.load_model("Helsinki-NLP/opus-mt-en-fr", "integrated_gradients")
out = model.attribute(
  "The developer argued with the designer because her idea cannot be implemented.",
  n_steps=100
)
out.show()
# Out:
# Loading weights: 100%|██████████| 258/258 [00:00<00:00, 2896.47it/s, Materializing param=model.shared.weight]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Attributing with integrated_gradients...: 100%|██████████| 22/22 [00:15<00:00,  1.35it/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 8
#       3 model = inseq.load_model("Helsinki-NLP/opus-mt-en-fr", "integrated_gradients")
#       4 out = model.attribute(
#       5   "The developer argued with the designer because her idea cannot be implemented.",
#       6   n_steps=100
#       7 )
# ----> 8 out.show()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pwm/lib/python3.11/site-packages/inseq/data/attribution.py:1050, in FeatureAttributionOutput.show(self, min_val, max_val, max_show_size, show_dim, slice_dims, display, return_html, return_figure, aggregator, do_aggregation, **kwargs)
#    1048 out_figs = []
#    1049 for attr in self.sequence_attributions:
# -> 1050     curr_out = attr.show(
#    1051         min_val=min_val,
#    1052         max_val=max_val,
#    1053         max_show_size=max_show_size,
#    1054         show_dim=show_dim,
#    1055         slice_dims=slice_dims,
#    1056         display=display,
#    1057         return_html=return_html,
#    1058         return_figure=return_figure,
#    1059         aggregator=aggregator,
#    1060         do_aggregation=do_aggregation,
#    1061         **kwargs,
#    1062     )
#    1063     if return_html:
#    1064         out_str += curr_out
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pwm/lib/python3.11/site-packages/inseq/data/attribution.py:501, in FeatureAttributionSequenceOutput.show(self, min_val, max_val, max_show_size, show_dim, slice_dims, display, return_html, return_figure, aggregator, do_aggregation, **kwargs)
#     495     logger.warning(f"Found empty attributions, skipping attribution matching generation: {tokens}")
#     496 if (
#     497     (aggregated.source_attributions is not None and aggregated.source_attributions.ndim == 2)
#     498     or (aggregated.target_attributions is not None and aggregated.target_attributions.ndim == 2)
#     499     or (aggregated.source_attributions is None and aggregated.target_attributions is None)
#     500 ):
# --> 501     return show_attributions(
#     502         attributions=aggregated, min_val=min_val, max_val=max_val, display=display, return_html=return_html
#     503     )
#     504 else:
#     505     return show_granular_attributions(
#     506         attributions=aggregated,
#     507         max_show_size=max_show_size,
#    (...)    514         slice_dims=slice_dims,
#     515     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pwm/lib/python3.11/site-packages/inseq/data/viz.py:117, in show_attributions(attributions, min_val, max_val, display, return_html)
#     115     curr_html += get_heatmap_type(attribution, curr_html_color, "Target", use_html=True)
#     116 if display and isnotebook():
# --> 117     from IPython.core.display import HTML, display
#     119     display(HTML(curr_html))
#     120 html_out += curr_html
#
# ImportError: cannot import name 'display' from 'IPython.core.display' (/opt/homebrew/Caskroom/miniforge/base/envs/pwm/lib/python3.11/site-packages/IPython/core/display.py)

# %%
print(out)
# Out:
# FeatureAttributionOutput({
#     sequence_attributions: list with 1 elements of type GranularFeatureAttributionSequenceOutput: [
#         GranularFeatureAttributionSequenceOutput({
#             source: list with 14 elements of type TokenWithId: [
#                 '▁The', '▁developer', '▁argued', '▁with', '▁the', '▁designer', '▁because', '▁her', '▁idea', '▁cannot', '▁be', '▁implemented', '.', '</s>'
#             ],
#             target: list with 22 elements of type TokenWithId,
#             source_attributions: torch.float32 tensor of shape [14, 21, 512] on cpu,
#             target_attributions: None,
#             step_scores: {},
#             sequence_scores: {},
#             attr_pos_start: 1,
#             attr_pos_end: 22,
#         })
#     ],
#     step_attributions: None,
#     info: {
#         attribution_method: "integrated_gradients",
#         attr_pos_start: 1,
#         attr_pos_end: 22,
#         output_step_attributions: False,
#         attribute_target: False,
#         step_scores: list with 0 elements,
#         exec_time: 15.54408,
#         model_name: "Helsinki-NLP/opus-mt-en-fr",
#         model_class: "MarianMTModel",
#         tokenizer_name: None,
#         tokenizer_class: "MarianTokenizer",
#         include_eos_baseline: False,
#         attributed_fn: "probability_fn",
#         attribution_args: {
#             n_steps: 100,
#         },
#         attributed_fn_args: {},
#         step_scores_args: {},
#         input_texts: list with 1 elements of type str: [
#             'The developer argued with the designer because her idea cannot be implemented.'
#         ],
#         generated_texts: list with 1 elements of type str: [
#             'Le développeur a argumenté avec le concepteur parce que son idée ne peut pas être mise en œuvre.'
#         ],
#         generation_args: {},
#         constrained_decoding: False,
#         generate_from_target_prefix: False,
#     },
# })
